# %%
def greet(name):
  print("Welcome",name)
greet("Students")
# Out:
# Welcome Students

# %%
def greet():
  print("Hello")
greet()
# Out:
# Hello

# %%
def add(a,b):
  return a+b
result=add(10,20)
print(result)
# Out:
# 30
