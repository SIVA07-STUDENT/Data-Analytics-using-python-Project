# %%
try:
  num=int(input("enter:"))
except:
  print("Invalid input")
# Out:
# enter:abc
# Invalid input

# %%
import numpy as np
marks=np.array([90,85,78,92])
print(marks)
# Out:
# [90 85 78 92]

# %%
import numpy as  np
students=np.array([
    [90,85],
    [78,92],
    [88,45],
])
print(students)
# Out:
# [[90 85]
#  [78 92]
#  [88 45]]

# %%
import numpy as  np
arr=np.zeros((2,3))
print(arr)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np
marks=np.array([98,85,78,92])
print(marks[2])
# Out:
# 78

# %%
import numpy as np
marks=np.array([98,85,78,63,87,94])
print(marks[1:4])
# Out:
# [85 78 63]
