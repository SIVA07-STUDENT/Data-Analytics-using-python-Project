# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVA07-STUDENT/Data-Analytics-using-python-Project/blob/main/Phython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("enter mark 1:"))
mark2=int(input("enter mark 2:"))
mark3=int(input("enter mark 3:"))

total=mark1+mark2+mark3
average=total/3

print("total",total)
print("average",average)

if average >= 50:
   print("pass")
else:
   print("fail")
# Out:
# enter mark 1:10
# enter mark 2:20
# enter mark 3:30
# total 60
# average 20.0
# fail
