# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVA07-STUDENT/Data-Analytics-using-python-Project/blob/main/practical_day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("enter mark 1:"))
mark2=int(input("enter mark2:"))
mark3=int(input("enter mark3:"))
total=mark1+mar2+mark3
average=total/3
print("total:",total)
print("average;",average)
if average>=90:
  print("Grade A")
elif average>=75:
  print("Grade B")
elif average
