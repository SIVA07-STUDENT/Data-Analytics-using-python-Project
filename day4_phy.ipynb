# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVA07-STUDENT/Data-Analytics-using-python-Project/blob/main/day4_phy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
new_arr=arr.reshape(2,3)
print(new_arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
marks=np.array([70,80,50,60])
average=np.mean(marks)
print(average)
# Out:
# 65.0

# %%
import numpy as np
salary=np.array([10000,20000,30000,40000,50000])
med=np.median(salary)
print(med)
# Out:
# 30000.0
